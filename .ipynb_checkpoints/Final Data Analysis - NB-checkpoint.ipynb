# %% [markdown]
# # Analysis

# %% [markdown]
# ## Intro

# %% [markdown]
# ## Crime Rate (by State) - Heat Map

# %% [markdown]
# ## Income (by State) - Choropleth Map

# %%
import os
import pandas as pd
import plotly
import plotly.plotly as py
import numpy as np
import matplotlib.pyplot as plt

# %%
plotly.tools.set_credentials_file(username='navbala', api_key='bOGG51FtSjmAQ3FAzksA')

# %%
median_income_df = pd.read_csv(os.path.join('formatted','median_income.csv'))
median_income_df.head()
# Out:
#            State   2016   2015   2014   2013   2012   2011   2010   2009  \
# 0  United States  59039  56516  53657  53585  51017  50054  49276  49777
# 1             AL  47221  44509  42278  47320  43464  42590  40933  39980
# 2             AK  75723  75112  67629  72472  63648  57431  57848  61604
# 3             AZ  57100  52248  49254  52611  47044  48621  46896  45739
# 4             AR  45907  42798  44922  39376  39018  41302  38587  36538
#
#     2008  ...     1993   1992   1991   1990   1989   1988   1987   1986  \
# 0  50303  ...    31241  30636  30126  29943  28906  27225  26061  24897
# 1  44476  ...    25082  25808  24346  23357  21284  19948  19734  19132
# 2  63989  ...    42931  41802  40612  39298  36006  33103  33233  31356
# 3  46914  ...    30510  29358  30737  29224  28552  26435  26749  25500
# 4  39586  ...    23039  23882  23435  22786  21433  20172  18827  18730
#
#     1985   1984
# 0  23618  22415
# 1  18333  17310
# 2  34782  32356
# 3  23877  21425
# ...

# %%
median_income_df = median_income_df.drop(median_income_df.index[0])
## MAY need to reset index
median_income_df.head()
# Out:
#   State   2016   2015   2014   2013   2012   2011   2010   2009   2008  ...    \
# 1    AL  47221  44509  42278  47320  43464  42590  40933  39980  44476  ...
# 2    AK  75723  75112  67629  72472  63648  57431  57848  61604  63989  ...
# 3    AZ  57100  52248  49254  52611  47044  48621  46896  45739  46914  ...
# 4    AR  45907  42798  44922  39376  39018  41302  38587  36538  39586  ...
# 5    CA  66637  63636  60487  60794  57020  53367  54283  56134  57014  ...
#
#     1993   1992   1991   1990   1989   1988   1987   1986   1985   1984
# 1  25082  25808  24346  23357  21284  19948  19734  19132  18333  17310
# 2  42931  41802  40612  39298  36006  33103  33233  31356  34782  32356
# 3  30510  29358  30737  29224  28552  26435  26749  25500  23877  21425
# 4  23039  23882  23435  22786  21433  20172  18827  18730  17451  15674
# 5  34073  34903  33664  33290  33009  30287  30146  29010  26981  25287
#
# [5 rows x 34 columns]

# %%
## Create heat map (when state is not the index)
## For just 2016 as demo

scl = [[0.0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'],\
            [0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]


data = [ dict(
        type='choropleth',
        colorscale = scl,
        autocolorscale = False,
        locations = median_income_df.index,
        z = median_income_df['2016'].astype(float),
        locationmode = 'USA-states',
        text = median_income_df['2016'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Income USD")
        ) ]

layout = dict(
        title = '2016 Household Income by State<br>(Hover for breakdown)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict( data=data, layout=layout )
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~navbala/0 or inside your plot.ly account where it is named 'd3-cloropleth-map'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~navbala/0.embed" height="525px" width="100%"></iframe>

# %%
income_df = median_income_df.set_index(["State"])
income_df.head()
# Out:
#         2016   2015   2014   2013   2012   2011   2010   2009   2008   2007  \
# State
# AL     47221  44509  42278  47320  43464  42590  40933  39980  44476  42212
# AK     75723  75112  67629  72472  63648  57431  57848  61604  63989  62993
# AZ     57100  52248  49254  52611  47044  48621  46896  45739  46914  47215
# AR     45907  42798  44922  39376  39018  41302  38587  36538  39586  40795
# CA     66637  63636  60487  60794  57020  53367  54283  56134  57014  55734
#
#        ...     1993   1992   1991   1990   1989   1988   1987   1986   1985  \
# State  ...
# AL     ...    25082  25808  24346  23357  21284  19948  19734  19132  18333
# AK     ...    42931  41802  40612  39298  36006  33103  33233  31356  34782
# AZ     ...    30510  29358  30737  29224  28552  26435  26749  25500  23877
# AR     ...    23039  23882  23435  22786  21433  20172  18827  18730  17451
# CA     ...    34073  34903  33664  33290  33009  30287  30146  29010  26981
#
#         1984
# State
# ...

# %%
# Get max (state, income) from each column

# for year in income_df.iteritems():
#     print(np.max(year))

# %%
## Create heat map (state is index)
## For just 2016 as demo

scl = [[0.0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'],\
            [0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]


data = [ dict(
        type='choropleth',
        colorscale = scl,
        autocolorscale = False,
        locations = income_df.index,
        z = income_df['2016'].astype(float),
        locationmode = 'USA-states',
        text = income_df['2016'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Income USD")
        ) ]

layout = dict(
        title = '2016 Household Income by State<br>(Hover for breakdown)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict( data=data, layout=layout )
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~navbala/0 or inside your plot.ly account where it is named 'd3-cloropleth-map'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~navbala/0.embed" height="525px" width="100%"></iframe>

# %%
# Make heat map loop through all the years
# Create initial heat map

scl = [[0.0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'],\
                [0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]


for year in income_df.iteritems:

    

    data = [ dict(
            type='choropleth',
            colorscale = scl,
            autocolorscale = False,
            locations = state,
            z = year.astype(float),
            locationmode = 'USA-states',
            text = year,
            marker = dict(
                line = dict (
                    color = 'rgb(255,255,255)',
                    width = 2
                ) ),
            colorbar = dict(
                title = "Income USD")
            ) ]

    layout = dict(
            title = '2016 Household Income by State<br>(Hover for breakdown)',
            geo = dict(
                scope='usa',
                projection=dict( type='albers usa' ),
                showlakes = True,
                lakecolor = 'rgb(255, 255, 255)'),
                 )

    fig = dict( data=data, layout=layout )
    py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-e9f992188e4d> in <module>()
#       5
#       6
# ----> 7 for year in income_df.iteritems:
#       8
#       9
#
# TypeError: 'method' object is not iterable

# %%
income_df.head()
# Out:
#         2016   2015   2014   2013   2012   2011   2010   2009   2008   2007  \
# State
# AL     47221  44509  42278  47320  43464  42590  40933  39980  44476  42212
# AK     75723  75112  67629  72472  63648  57431  57848  61604  63989  62993
# AZ     57100  52248  49254  52611  47044  48621  46896  45739  46914  47215
# AR     45907  42798  44922  39376  39018  41302  38587  36538  39586  40795
# CA     66637  63636  60487  60794  57020  53367  54283  56134  57014  55734
#
#        ...     1993   1992   1991   1990   1989   1988   1987   1986   1985  \
# State  ...
# AL     ...    25082  25808  24346  23357  21284  19948  19734  19132  18333
# AK     ...    42931  41802  40612  39298  36006  33103  33233  31356  34782
# AZ     ...    30510  29358  30737  29224  28552  26435  26749  25500  23877
# AR     ...    23039  23882  23435  22786  21433  20172  18827  18730  17451
# CA     ...    34073  34903  33664  33290  33009  30287  30146  29010  26981
#
#         1984
# State
# ...

# %%
income_df_formatted = income_df[income_df.columns[::-1]]
income_df_formatted = income_df_formatted.drop(['1984','1985','1986','1987','1988','1989','1990','1991','1992','1993','1994'], axis=1)
income_df_formatted.head()
# Out:
#         1995   1996   1997   1998   1999   2000   2001   2002   2003   2004  \
# State
# AL     25991  30302  31939  36266  36251  35424  35160  37603  37255  36629
# AK     47954  52779  47994  50692  51396  52847  57363  52774  51837  55063
# AZ     30863  31637  32740  37090  36995  39783  42704  39734  41166  43846
# AR     25814  27123  26162  27665  29682  29697  33339  32387  32002  34984
# CA     37009  38812  39694  40934  43629  46816  47262  47437  49300  49222
#
#        ...     2007   2008   2009   2010   2011   2012   2013   2014   2015  \
# State  ...
# AL     ...    42212  44476  39980  40933  42590  43464  47320  42278  44509
# AK     ...    62993  63989  61604  57848  57431  63648  72472  67629  75112
# AZ     ...    47215  46914  45739  46896  48621  47044  52611  49254  52248
# AR     ...    40795  39586  36538  38587  41302  39018  39376  44922  42798
# CA     ...    55734  57014  56134  54283  53367  57020  60794  60487  63636
#
#         2016
# State
# ...

# %%
avg_med_income = income_df_formatted.mean()
years = avg_med_income.keys()
# Out:
# Index(['1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016'],
#       dtype='object')

# %%
avg_med_income.head()
# Out:
# 1995    33814.098039
# 1996    35122.098039
# 1997    36603.921569
# 1998    38551.058824
# 1999    40251.392157
# dtype: float64

# %%
# Plot Line graph
plt.plot(income_df_formatted.columns, income_df_formatted.loc['TX'], color="green",label=income_df_formatted.loc['TX'])

plt.show()

# %%
# loop through to select top 5 states 
counter = 0
for index, row in income_df_formatted.iterrows():
    x = income_df_formatted.columns
    y= row.values
    plt.plot(x, y,label = index)
    
    # TESTING - Counter to test looping through state(rows)
    counter += 1
    if counter == 5:
        break
        
plt.xlabel("Years")
plt.ylabel("Median Household Income")
plt.title("Income vs. Years")
plt.legend()
plt.show()

# %%
# loop through all states
for index, row in income_df_formatted.iterrows():
    x = income_df_formatted.columns
    y= row.values
    plt.plot(x, y, label = index)

        
plt.xlabel("Years")
plt.ylabel("Median Household Income")
plt.title("Income vs. Years")

plt.show()

# %%
# Highest incomes

#highest_incomes = income_df_formatted.groupby(["State"]).mean()
#highest_incomes = income_df_formatted.nlargest(5, :)
highest_incomes
# Out:
#         1995   1996   1997   1998   1999   2000   2001   2002   2003   2004  \
# State
# AK     47954  52779  47994  50692  51396  52847  57363  52774  51837  55063
# AL     25991  30302  31939  36266  36251  35424  35160  37603  37255  36629
# AR     25814  27123  26162  27665  29682  29697  33339  32387  32002  34984
# AZ     30863  31637  32740  37090  36995  39783  42704  39734  41166  43846
# CA     37009  38812  39694  40934  43629  46816  47262  47437  49300  49222
# CO     40706  40950  43233  46599  48177  48240  49397  48294  49940  50886
# CT     40243  42119  43985  46508  50593  50172  53347  53387  54965  55100
# D.C.   30748  31966  31860  33433  38670  41222  41169  39070  45044  43451
# DE     34928  39309  43033  41458  46628  50365  49602  49650  49019  48049
# FL     29745  30641  32455  34909  35831  38856  36421  38024  38972  40535
# GA     34099  32496  36663  38665  39425  41901  42576  42939  42438  40984
# ...

# %%
# loop through to select top 5 states 
counter = 0
for index, row in income_df_formatted.iterrows():
    x = income_df_formatted.columns
    y= row.values
    plt.plot(x, y,label = index)
    
    # Loop thorugh 5 highest incomes
    if 
     y= row.values
    plt.plot(x, y,label = index)
    
        
plt.xlabel("Years")
plt.ylabel("Median Household Income")
plt.title("Income vs. Years")
plt.legend()
plt.show()

# %% [markdown]
# ## Unemployment (by State) - Map
